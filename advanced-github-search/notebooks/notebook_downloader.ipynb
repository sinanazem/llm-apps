# %%
import os
import requests
import json

def fetch_repo_content(repo_owner, repo_name, path=''):
    api_url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/contents/{path}"
    headers = {'Accept': 'application/vnd.github.v3+json'}
    try:
        response = requests.get(api_url, headers=headers)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch repo content: {e}")
        return None

def download_file(file_url, local_file_path):
    try:
        response = requests.get(file_url)
        response.raise_for_status()
        os.makedirs(os.path.dirname(local_file_path), exist_ok=True)
        with open(local_file_path, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded: {file_url} to {local_file_path}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download file {file_url}: {e}")

def process_github_repo(repo_owner, repo_name, metadata_output_path):
    contents = fetch_repo_content(repo_owner, repo_name)
    if contents is None:
        return

    base_raw_url = f"https://raw.githubusercontent.com/{repo_owner}/{repo_name}/main"
    base_main_github_url = f"https://github.com/{repo_owner}/{repo_name}/blob/main"
    metadata = {}

    stack = [('', contents)]
    while stack:
        current_path, directory_contents = stack.pop()
        for item in directory_contents:
            if item['type'] == 'file' and item['name'].endswith('.ipynb'):
                file_path = item['path']
                raw_file_url = f"{base_raw_url}/{file_path.replace(' ', '%20')}"
                github_url = f"{base_main_github_url}/{file_path.replace(' ', '%20')}"
                local_file_path = os.path.join("downloaded_files", file_path)

                # Download the notebook
                download_file(raw_file_url, local_file_path)

                # Store both raw and main GitHub URLs in metadata
                metadata[local_file_path] = {
                    "raw_url": raw_file_url,
                    "github_url": github_url
                }
            
            elif item['type'] == 'dir':
                # Fetch contents of the directory
                sub_dir_contents = fetch_repo_content(repo_owner, repo_name, item['path'])
                if sub_dir_contents:
                    stack.append((item['path'], sub_dir_contents))

    # Save metadata to a JSON file
    with open(metadata_output_path, 'w', encoding='utf-8') as metadata_file:
        json.dump(metadata, metadata_file, ensure_ascii=False, indent=4)

    print(f"Metadata saved to {metadata_output_path}")

# Usage
repo_owner = 'pytopia'
repo_name = 'Python-Programming'
metadata_output_file = 'notebook_metadata.json'
process_github_repo(repo_owner, repo_name, metadata_output_file)
# Out:
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/01%20Project%20Proposal.ipynb to downloaded_files/Lectures/12 Capstone Project/01 Project Proposal.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/02%20Requirements%20Gathering.ipynb to downloaded_files/Lectures/12 Capstone Project/02 Requirements Gathering.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/03%20Design%20and%20Planning.ipynb to downloaded_files/Lectures/12 Capstone Project/03 Design and Planning.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/04%20Setting%20Up%20the%20Development%20Environment.ipynb to downloaded_files/Lectures/12 Capstone Project/04 Setting Up the Development Environment.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/05%20Modular%20Design%20and%20Code%20Organization.ipynb to downloaded_files/Lectures/12 Capstone Project/05 Modular Design and Code Organization.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/06%20Coding%20and%20Implementation.ipynb to downloaded_files/Lectures/12 Capstone Project/06 Coding and Implementation.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/07%20Testing%20and%20Debugging.ipynb to downloaded_files/Lectures/12 Capstone Project/07 Testing and Debugging.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures
ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/--%2007%20Debugging%20Techniques%20in%20VSCode.ipynb to downloaded_files/Lectures/10 Modular Programming/-- 07 Debugging Techniques in VSCode.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/01%20Limitations%20of%20Jupyter%20Notebooks.ipynb to downloaded_files/Lectures/10 Modular Programming/01 Limitations of Jupyter Notebooks.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/02%20Modular%20Programming.ipynb to downloaded_files/Lectures/10 Modular Programming/02 Modular Programming.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/03%20Creating%20and%20Importing%20Modules.ipynb to downloaded_files/Lectures/10 Modular Programming/03 Creating and Importing Modules.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/04%20The%20Python%20Module%20Search%20Path.ipynb to downloaded_files/Lectures/10 Modular Programming/04 The Python Module Search Path.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/05%20Creating%20and%20Using%20Packages.ipynb to downloaded_files/Lectures/10 Modular Programming/05 Creating and Using Packages.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/06%20Common%20Issues%20in%20Python%20Packages.ipynb to downloaded_files/Lectures/10 Modular Programming/06 Common Issues in Python Packages.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/07%20Basics%20of%20Debugging%20in%20VSCode.ipynb to downloaded_files/Lectures/10 Modular Programming/07 Basics of Debugging in VSCode.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/08%20Advanced%20Debugging%20Techniques%20in%20VSCode.ipynb to downloaded_files/Lectures/10 Modular Programming/08 Advanced Debugging Techniques in VSCode.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/01%20Programming%20Paradigms.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/01 Programming Paradigms.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/02%20Introduction%20to%20Object%20Oriented%20Programming.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/02 Introduction to Object Oriented Programming.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/03%20OOP%20in%20Python.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/03 OOP in Python.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/04%20Classes%20and%20Objects.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/04 Classes and Objects.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/05%20the%20__init__%20Method.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/05 the __init__ Method.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/06%20OOP%20Feature:%20Inheritance.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/06 OOP Feature: Inheritance.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/07%20Types%20of%20Inheritance.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/07 Types of Inheritance.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/08%20Object%20Relationships.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/08 Object Relationships.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/09%20OOP%20Feature:%20Polymorphism.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/09 OOP Feature: Polymorphism.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/10%20OOP%20Feature:%20Encapsulation.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/10 OOP Feature: Encapsulation.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/11%20OOP%20Feature:%20Abstract%20Base%20Classes.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/11 OOP Feature: Abstract Base Classes.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/12%20Overriding.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/12 Overriding.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/13%20The%20Magic%20Methods.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/13 The Magic Methods.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/14%20Static%20and%20Class%20Methods.ipynb to downloaded_files/Lectures/09 Object Oriented Programming/14 Static and Class Methods.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures
ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/08%20Installing%20Conda.ipynb to downloaded_files/Lectures/02 Python Setup/08 Installing Conda.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/09%20Python%20Package%20Management%20System.ipynb to downloaded_files/Lectures/02 Python Setup/09 Python Package Management System.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/10%20Managing%20Python%20Packages%20with%20Conda.ipynb to downloaded_files/Lectures/02 Python Setup/10 Managing Python Packages with Conda.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/11%20Using%20Conda%20Environments%20in%20VS%20Code.ipynb to downloaded_files/Lectures/02 Python Setup/11 Using Conda Environments in VS Code.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/12%20Setting%20Up%20Jupyter%20Notebook%20with%20Conda.ipynb to downloaded_files/Lectures/02 Python Setup/12 Setting Up Jupyter Notebook with Conda.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/01%20Early%20Programming.ipynb to downloaded_files/Lectures/01 Introduction/01 Early Programming.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/02%20Programming%20Languages.ipynb to downloaded_files/Lectures/01 Introduction/02 Programming Languages.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/03%20Why%20Choose%20Python.ipynb to downloaded_files/Lectures/01 Introduction/03 Why Choose Python.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/04%20Python%20Features%20and%20Applications.ipynb to downloaded_files/Lectures/01 Introduction/04 Python Features and Applications.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/05%20How%20Long%20Does%20it%20Take%20to%20Learn%20Python.ipynb to downloaded_files/Lectures/01 Introduction/05 How Long Does it Take to Learn Python.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/06%20Python%20Versions.ipynb to downloaded_files/Lectures/01 Introduction/06 Python Versions.ipynb
# Downloaded: https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/07%20Effective%20Question%20Asking.ipynb to downloaded_files/Lectures/01 Introduction/07 Effective Question Asking.ipynb
# Metadata saved to notebook_metadata.json

# %%
import json

def read_json_file(file_path):
    """
    Reads JSON data from a file and returns it as a Python dictionary.

    :param file_path: Path to the JSON file.
    :return: Parsed JSON data as a dictionary or list.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
            return data
    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file {file_path} contains invalid JSON.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
notebook_metadata = read_json_file('notebook_metadata.json')

# %%
notebook_metadata
# Out:
# {'downloaded_files/Lectures/12 Capstone Project/01 Project Proposal.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/01%20Project%20Proposal.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/12%20Capstone%20Project/01%20Project%20Proposal.ipynb'},
#  'downloaded_files/Lectures/12 Capstone Project/02 Requirements Gathering.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/02%20Requirements%20Gathering.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/12%20Capstone%20Project/02%20Requirements%20Gathering.ipynb'},
#  'downloaded_files/Lectures/12 Capstone Project/03 Design and Planning.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/03%20Design%20and%20Planning.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/12%20Capstone%20Project/03%20Design%20and%20Planning.ipynb'},
#  'downloaded_files/Lectures/12 Capstone Project/04 Setting Up the Development Environment.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/12%20Capstone%20Project/04%20Setting%20Up%20the%20Development%20Environment.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/12%20Capstone%20Project/04%20Setting%20Up%20the%20Development%20Environment.ipynb'},
#  'downloaded_files/Lectures/12 Capstone Project/05 Modular Design and Code Organization.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures
ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/03%20Creating%20and%20Importing%20Modules.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/10%20Modular%20Programming/03%20Creating%20and%20Importing%20Modules.ipynb'},
#  'downloaded_files/Lectures/10 Modular Programming/04 The Python Module Search Path.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/04%20The%20Python%20Module%20Search%20Path.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/10%20Modular%20Programming/04%20The%20Python%20Module%20Search%20Path.ipynb'},
#  'downloaded_files/Lectures/10 Modular Programming/05 Creating and Using Packages.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/05%20Creating%20and%20Using%20Packages.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/10%20Modular%20Programming/05%20Creating%20and%20Using%20Packages.ipynb'},
#  'downloaded_files/Lectures/10 Modular Programming/06 Common Issues in Python Packages.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/06%20Common%20Issues%20in%20Python%20Packages.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/10%20Modular%20Programming/06%20Common%20Issues%20in%20Python%20Packages.ipynb'},
#  'downloaded_files/Lectures/10 Modular Programming/07 Basics of Debugging in VSCode.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/07%20Basics%20of%20Debugging%20in%20VSCode.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/10%20Modular%20Programming/07%20Basics%20of%20Debugging%20in%20VSCode.ipynb'},
#  'downloaded_files/Lectures/10 Modular Programming/08 Advanced Debugging Techniques in VSCode.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/10%20Modular%20Programming/08%20Advanced%20Debugging%20Techniques%20in%20VSCode.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/10%20Modular%20Programming/08%20Advanced%20Debugging%20Techniques%20in%20VSCode.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/01 Programming Paradigms.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/01%20Programming%20Paradigms.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/01%20Programming%20Paradigms.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/02 Introduction to Object Oriented Programming.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/02%20Introduction%20to%20Object%20Oriented%20Programming.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/02%20Introduction%20to%20Object%20Oriented%20Programming.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/03 OOP in Python.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/03%20OOP%20in%20Python.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/03%20OOP%20in%20Python.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/04 Classes and Objects.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/04%20Classes%20and%20Objects.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/04%20Classes%20and%20Objects.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/05 the __init__ Method.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/05%20the%20__init__%20Method.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/05%20the%20__init__%20Method.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/06 OOP Feature: Inheritance.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/06%20OOP%20Feature:%20Inheritance.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/06%20OOP%20Feature:%20Inheritance.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/07 Types of Inheritance.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/07%20Types%20of%20Inheritance.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/07%20Types%20of%20Inheritance.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/08 Object Relationships.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming/08%20Object%20Relationships.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/09%20Object%20Oriented%20Programming/08%20Object%20Relationships.ipynb'},
#  'downloaded_files/Lectures/09 Object Oriented Programming/09 OOP Feature: Polymorphism.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/09%20Object%20Oriented%20Programming
ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/07%20Functions/08%20Built-in%20Functions.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/07%20Functions/08%20Built-in%20Functions.ipynb'},
#  'downloaded_files/Lectures/06 Control Structures/01 Introduction to Control Structures.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/06%20Control%20Structures/01%20Introduction%20to%20Control%20Structures.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/06%20Control%20Structures/01%20Introduction%20to%20Control%20Structures.ipynb'},
#  'downloaded_files/Lectures/06 Control Structures/02 Conditional Statements.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/06%20Control%20Structures/02%20Conditional%20Statements.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/06%20Control%20Structures/02%20Conditional%20Statements.ipynb'},
#  'downloaded_files/Lectures/06 Control Structures/03 for Loops.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/06%20Control%20Structures/03%20for%20Loops.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/06%20Control%20Structures/03%20for%20Loops.ipynb'},
#  'downloaded_files/Lectures/06 Control Structures/04 while Loops.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/06%20Control%20Structures/04%20while%20Loops.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/06%20Control%20Structures/04%20while%20Loops.ipynb'},
#  'downloaded_files/Lectures/06 Control Structures/05 Loop Control Statements.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/06%20Control%20Structures/05%20Loop%20Control%20Statements.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/06%20Control%20Structures/05%20Loop%20Control%20Statements.ipynb'},
#  'downloaded_files/Lectures/06 Control Structures/06 Comprehensions.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/06%20Control%20Structures/06%20Comprehensions.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/06%20Control%20Structures/06%20Comprehensions.ipynb'},
#  'downloaded_files/Lectures/05 Code Structure and Syntax/01 Introduction.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/05%20Code%20Structure%20and%20Syntax/01%20Introduction.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/05%20Code%20Structure%20and%20Syntax/01%20Introduction.ipynb'},
#  'downloaded_files/Lectures/05 Code Structure and Syntax/02 Line Continuation.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/05%20Code%20Structure%20and%20Syntax/02%20Line%20Continuation.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/05%20Code%20Structure%20and%20Syntax/02%20Line%20Continuation.ipynb'},
#  'downloaded_files/Lectures/05 Code Structure and Syntax/03 Comments.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/05%20Code%20Structure%20and%20Syntax/03%20Comments.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/05%20Code%20Structure%20and%20Syntax/03%20Comments.ipynb'},
#  'downloaded_files/Lectures/05 Code Structure and Syntax/04 Whitespace and Indentation.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/05%20Code%20Structure%20and%20Syntax/04%20Whitespace%20and%20Indentation.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/05%20Code%20Structure%20and%20Syntax/04%20Whitespace%20and%20Indentation.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/01 Basic Data Types.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types/01%20Basic%20Data%20Types.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/01%20Basic%20Data%20Types.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/02 Variables.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types/02%20Variables.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/02%20Variables.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/03 Conversion Between Data Types.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types/03%20Conversion%20Between%20Data%20Types.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/03%20Conversion%20Between%20Data%20Types.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/04 Operators and Expresssions.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types/04%20Operators%20and%20Expresssions.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/04%20Operators%20and%20Expresssions.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/05 Objects in Python.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types/05%20Objects%20in%20Python.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/05%20Objects%20in%20Python.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/06 Strings.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types/06%20Strings.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/06%20Strings.ipynb'},
#  'downloaded_files/Lectures/04 Data Types/07 Basic String Operations.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/04%20Data%20Types
ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/01%20Introduction%20to%20Python%20Development%20Environment.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/01%20Introduction%20to%20Python%20Development%20Environment.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/02 Operating Systems and Terminal Setup.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/02%20Operating%20Systems%20and%20Terminal%20Setup.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/02%20Operating%20Systems%20and%20Terminal%20Setup.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/03 How the File System Works in Unix-Based Systems.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/03%20How%20the%20File%20System%20Works%20in%20Unix-Based%20Systems.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/03%20How%20the%20File%20System%20Works%20in%20Unix-Based%20Systems.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/04 Command-Line Crash Course.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/04%20Command-Line%20Crash%20Course.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/04%20Command-Line%20Crash%20Course.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/05 Installing VS Code.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/05%20Installing%20VS%20Code.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/05%20Installing%20VS%20Code.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/06 Getting Started with Visual Studio Code.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/06%20Getting%20Started%20with%20Visual%20Studio%20Code.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/06%20Getting%20Started%20with%20Visual%20Studio%20Code.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/07 What is a Package Manager.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/07%20What%20is%20a%20Package%20Manager.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/07%20What%20is%20a%20Package%20Manager.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/08 Installing Conda.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/08%20Installing%20Conda.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/08%20Installing%20Conda.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/09 Python Package Management System.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/09%20Python%20Package%20Management%20System.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/09%20Python%20Package%20Management%20System.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/10 Managing Python Packages with Conda.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/10%20Managing%20Python%20Packages%20with%20Conda.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/10%20Managing%20Python%20Packages%20with%20Conda.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/11 Using Conda Environments in VS Code.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/11%20Using%20Conda%20Environments%20in%20VS%20Code.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/11%20Using%20Conda%20Environments%20in%20VS%20Code.ipynb'},
#  'downloaded_files/Lectures/02 Python Setup/12 Setting Up Jupyter Notebook with Conda.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/02%20Python%20Setup/12%20Setting%20Up%20Jupyter%20Notebook%20with%20Conda.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/02%20Python%20Setup/12%20Setting%20Up%20Jupyter%20Notebook%20with%20Conda.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/01 Early Programming.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/01%20Early%20Programming.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/01%20Early%20Programming.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/02 Programming Languages.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/02%20Programming%20Languages.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/02%20Programming%20Languages.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/03 Why Choose Python.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/03%20Why%20Choose%20Python.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/03%20Why%20Choose%20Python.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/04 Python Features and Applications.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/04%20Python%20Features%20and%20Applications.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/04%20Python%20Features%20and%20Applications.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/05 How Long Does it Take to Learn Python.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/05%20How%20Long%20Does%20it%20Take%20to%20Learn%20Python.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/05%20How%20Long%20Does%20it%20Take%20to%20Learn%20Python.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/06 Python Versions.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/06%20Python%20Versions.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/06%20Python%20Versions.ipynb'},
#  'downloaded_files/Lectures/01 Introduction/07 Effective Question Asking.ipynb': {'raw_url': 'https://raw.githubusercontent.com/pytopia/Python-Programming/main/Lectures/01%20Introduction/07%20Effective%20Question%20Asking.ipynb',
#   'github_url': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/01%20Introduction/07%20Effective%20Question%20Asking.ipynb'}}

# %%
import os
import json
import nbformat
import re

def clean_toc(content):
    """
    Cleans up the "Table of Contents" content by extracting plain text headings.
    
    Parameters:
    - content (str): The raw markdown content of the TOC cell.
    
    Returns:
    - list of str: A list containing the plain text titles of each TOC entry.
    """
    lines = content.splitlines()
    cleaned_lines = []
    
    # Regular expression to find markdown list items with links
    toc_regex = re.compile(r'^\s*[-*]\s*\[(.*?)\]\(.*?\)\s*$')
    
    for line in lines:
        match = toc_regex.match(line)
        if match:
            cleaned_lines.append(match.group(1))
    
    return cleaned_lines

def clean_exercise(content):
    """
    Cleans the "Practice Exercise" content by removing markdown syntax and excess whitespace.
    
    Parameters:
    - content (str): The raw content of the exercise cell.
    
    Returns:
    - str: Cleaned content as plain text.
    """
    # Remove markdown links and other formatting
    cleaned_content = re.sub(r'\[.*?\]\(.*?\)', '', content)  # Remove markdown links
    cleaned_content = re.sub(r'^\s*[-*]\s*', '', cleaned_content, flags=re.MULTILINE)  # Remove list markers
    cleaned_content = re.sub(r'\s+', ' ', cleaned_content).strip()  # Reduce whitespace
    return cleaned_content

def extract_cells(directory, json_output_path, repo_url):
    """
    Extracts "Table of Contents" and "Practice Exercise" cells from all Jupyter notebooks in a directory,
    cleans them, and saves the information to a JSON file.
    
    Parameters:
    - directory (str): The directory path to search for Jupyter notebooks.
    - json_output_path (str): The path to save the output JSON file.
    - repo_url (str): The repository URL to include in the JSON output.
    """
    notebook_data = []

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".ipynb"):
                notebook_path = os.path.join(root, file)

                try:
                    with open(notebook_path, 'r', encoding='utf-8') as nb_file:
                        nb = nbformat.read(nb_file, as_version=4)

                        toc_content = ""
                        practice_exercises = []
                        capturing_exercise = False

                        for cell in nb.cells:
                            if cell.cell_type == 'markdown':
                                cell_text = cell.source.lower()

                                if "table of contents" in cell_text:
                                    toc_content = clean_toc(cell.source)
                                elif "practice exercise" in cell_text or "Exercise:" in cell_text:
                                    capturing_exercise = True
                                    practice_exercises.append(clean_exercise(cell.source))
                                elif capturing_exercise and re.match(r'^\s*#', cell.source):
                                    capturing_exercise = False

                            if capturing_exercise:
                                practice_exercises.append(clean_exercise(cell.source))

                        notebook_data.append({
                            "local_path": notebook_path,
                            "name": os.path.splitext(file)[0],
                            "table_of_content": toc_content,
                            "practice_exercises": practice_exercises,
                            "github_link": notebook_metadata[notebook_path]['github_url']
                        })
                except (nbformat.reader.NotJSONError, json.JSONDecodeError) as e:
                    print(f"Error reading {notebook_path}: {e}")

    with open(json_output_path, 'w', encoding='utf-8') as json_file:
        json.dump(notebook_data, json_file, ensure_ascii=False, indent=4)
    
    print(f"Notebook data saved to {json_output_path}")

if __name__ == "__main__":
    directory_to_search = "downloaded_files"  # Change this to your directory
    output_json_file = "notebooks_summary.json"
    repository_url = "https://github.com/pytopia/Python-Programming"  # Replace with your repository URL

    extract_cells(directory_to_search, output_json_file, repository_url)
# Out:
# Error reading downloaded_files/Lectures/11 Advanced Topics/-- Advanced Composite Data Types.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/-- Bitwise Operators.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/01 List Memory Management.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/02 Dictionary and Set Hash Table.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/03 Variable-length Arguments (*args and **kwargs).ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/04 Namespaces in Python.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/05 Variable Scope.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/06 Namespace Dictionaries.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/07 Modify Variables Out of Scope.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/08 Recursion.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/09 The with Statement and Context Managers.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/10 Dependency Management.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/25 Basic OOP Concepts.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/11 Advanced Topics/26 Custom Data Types using Classes.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/01 Project Proposal.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/02 Requirements Gathering.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/03 Design and Planning.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/04 Setting Up the Development Environment.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/05 Modular Design and Code Organization.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/06 Coding and Implementation.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/07 Testing and Debugging.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/08 Dcoumentation and User Guide.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/09 Conclusion.ipynb: Notebook does not appear to be JSON: ''
# Error reading downloaded_files/Lectures/12 Capstone Project/10 Course Wrap-up.ipynb: Notebook does not appear to be JSON: ''
# Notebook data saved to notebooks_summary.json

# %%
notebooks_summary = read_json_file('notebooks_summary.json')

# %%
notebooks_summary[41]
# Out:
# {'local_path': 'downloaded_files/Lectures/04 Data Types/22 Frozensets.ipynb',
#  'name': '22 Frozensets',
#  'table_of_content': ['Creating Frozen Sets in Python',
#   'Syntax for Creating a `frozenset`',
#   'Converting Other Iterables into Frozen Sets',
#   'Unique Elements in Frozen Sets',
#   'Immutable Sets vs. Mutable Sets',
#   'Conclusion',
#   'Accessing Frozen Set Elements',
#   'Membership Testing',
#   'Unordered Nature',
#   'Conversion to Ordered Sequence',
#   'Conclusion',
#   'Operations on Frozen Sets in Python',
#   'Immutable Nature and Implications',
#   'Set Operations with `frozenset`',
#   'Using Operators with `frozenset`',
#   'Combining `frozenset` with Other Sets',
#   'Immutable Results',
#   'Conclusion',
#   'Practical Applications of Frozen Sets',
#   'Frozen Sets as Dictionary Keys',
#   'Frozen Sets in Other Data Structures',
#   'Frozen Sets for Constant Set Definitions',
#   'Frozen Sets for Safe Data Sharing',
#   'Conclusion',
#   'Performance Considerations for Frozen Sets',
#   'Conclusion',
#   'Conclusion',
#   'Practice Exercise'],
#  'practice_exercises': ["## <a id='toc7_'></a>",
#   "## <a id='toc7_'></a>",
#   'To further solidify your understanding and skill in working with `frozenset`, here are some practical exercises to test your knowledge:',
#   "**Exercise 1: Creating and Using `frozenset`** Create a `frozenset` named `permissions` that contains the strings 'read', 'write', and 'execute'. Then, check to see if the permission 'delete' is included in the `permissions` set.",
#   '**Exercise 2: Set Operations with `frozenset`** Given `frozenset` A as `{1, 2, 3}` and `frozenset` B as `{2, 3, 4}`: Find the union of A and B. Determine the intersection. Calculate the difference between A and B.',
#   "**Exercise 3: Using `frozenset` as a Dictionary Key** Create a dictionary `graph` where each key is a `frozenset` representing an edge in a graph, and the value is the weight of that edge. Here's an example edge: a `frozenset` of nodes (1, 2) with an edge weight of 10. Add at least two more edges with different weights.",
#   "**Exercise 4: Converting to `frozenset`** Take the list `['apple', 'banana', 'apple', 'cherry']` and convert it into a `frozenset` named `unique_fruits`. Verify that duplicates have been removed by converting the `frozenset` back to a list and checking its contents."],
#  'github_link': 'https://github.com/pytopia/Python-Programming/blob/main/Lectures/04%20Data%20Types/22%20Frozensets.ipynb'}
